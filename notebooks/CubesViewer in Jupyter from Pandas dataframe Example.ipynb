# %% [markdown]
# # CubesViewer in Jupyter from Pandas dataframe

# %%
import os
import sys

sys.path.append("../")

# %load_ext autoreload
# %autoreload 2

# %%
import pandas
import cubesext

# %%
CSV_FILE = 'fakedata-product.csv'

df = pandas.read_csv(CSV_FILE)
df[:10]
# Out:
#      product_category product_subcategory  \
# 0  Office electronics         Calculators
# 1  Office electronics         Calculators
# 2  Office electronics         Calculators
# 3  Office electronics           Shredders
# 4  Office electronics           Shredders
# 5  Office electronics           Shredders
# 6  Office electronics            Printers
# 7  Office electronics            Printers
# 8  Office electronics            Printers
# 9  Office electronics          Appliances
#
#                                         product_name  product_price  \
# 0                                              TI-84         101.38
# 1                                             MS-80B           7.99
# 2                            P23 Printing Calculator          22.13
# 3                                  Burn-O-Matic 3000          29.99
# 4                          HideItShredder (720 cuts)          59.70
# 5                         ShredderMelter Pyromatic X          89.99
# 6                   Multifunction Machine PrintItAll         910.10
# 7                           Desktop A4 laser printer         249.16
# 8  GuttembergEco Movable Type Press (25 pages/h, 0W)         697.99
# 9                      SurpriseFlavor Coffee machine         299.99
#
#   product_unit             vendor  product_description
# 0        units  Tejas Instruments                  NaN
# 1        units             Ocasio                  NaN
# 2        units            Shannon                  NaN
# 3        units              Prost                  NaN
# 4        units              Prost                  NaN
# 5        units              Prost                  NaN
# 6        units            Shannon                  NaN
# 7        units            Shannon                  NaN
# 8        units            Shannon                  NaN
# 9        units              Prost                  NaN

# %%
(db_url, model_path) = cubesext.pandas2cubes(df)
print(db_url, model_path)
# Out:
# 2018-06-29 17:28:59,447 - INFO - Starting CubETL 1.0.5-devel
# 2018-06-29 17:28:59,510 - INFO - Connecting to database: sqlite:////tmp/cubesext-db-4kfh7hz1.sqlite3
# 2018-06-29 17:28:59,557 - INFO - Processing cubesutils.export-cubes
# Table: pandacube
#   Column: index [type=BIGINT, null=True, pk=False, fk=set()]
#     Cannot map column 'index' (type: BIGINT)
#   Column: product_category [type=TEXT, null=True, pk=False, fk=set()]
#   Column: product_subcategory [type=TEXT, null=True, pk=False, fk=set()]
#   Column: product_name [type=TEXT, null=True, pk=False, fk=set()]
#   Column: product_price [type=FLOAT, null=True, pk=False, fk=set()]
#   Column: product_unit [type=TEXT, null=True, pk=False, fk=set()]
#   Column: vendor [type=TEXT, null=True, pk=False, fk=set()]
#   Column: product_description [type=FLOAT, null=True, pk=False, fk=set()]
# {
#     "cubes": [
#         {
#             "_comment": "Generated by CubETL",
#             "aggregates": [
#                 {
#                     "function": "sum",
#                     "label": "product_price Sum",
#                     "measure": "product_price",
#                     "name": "product_price_sum"
#                 },
#                 {
#                     "function": "avg",
#                     "label": "product_price Avg",
#                     "measure": "product_price",
#                     "name": "product_price_avg"
#                 },
#                 {
#                     "function": "max",
#                     "label": "product_price Max",
#                     "measure": "product_price",
#                     "name": "product_price_max"
#                 },
#                 {
#                     "function": "min",
#                     "label": "product_price Min",
#                     "measure": "product_price",
#                     "name": "product_price_min"
#                 },
#                 {
#                     "function": "sum",
#                     "label": "product_description Sum",
#                     "measure": "product_description",
#                     "name": "product_description_sum"
#                 },
#                 {
#                     "function": "avg",
#                     "label": "product_description Avg",
#                     "measure": "product_description",
#                     "name": "product_description_avg"
#                 },
#                 {
#                     "function": "max",
#                     "label": "product_description Max",
#                     "measure": "product_description",
#                     "name": "product_description_max"
#                 },
#                 {
#                     "function": "min",
#                     "label": "product_description Min",
#                     "measure": "product_description",
#                     "name": "product_description_min"
#                 },
#                 {
#                     "function": "count",
#                     "label": "Record Count",
#                     "name": "record_count"
#                 }
#             ],
#             "details": [],
#             "dimensions": [
#                 "pandacube_product_category",
#                 "pandacube_product_subcategory",
#                 "pandacube_product_name",
#                 "pandacube_product_unit",
#                 "pandacube_vendor"
#             ],
#             "joins": [],
#             "key": "index",
#             "label": "pandacube",
#             "mappings": {
#                 "pandacube_product_category.pandacube_product_category": "pandacube.product_category",
#                 "pandacube_product_name.pandacube_product_name": "pandacube.product_name",
#                 "pandacube_product_subcategory.pandacube_product_subcategory": "pandacube.product_subcategory",
#                 "pandacube_product_unit.pandacube_product_unit": "pandacube.product_unit",
#                 "pandacube_vendor.pandacube_vendor": "pandacube.vendor"
#             },
#             "measures": [
#                 {
#                     "label": "product_price",
#                     "name": "product_price"
#                 },
#                 {
#                     "label": "product_description",
#                     "name": "product_description"
#                 }
#             ],
#             "name": "pandacube"
#         }
#     ],
#     "dimensions": [
#         {
#             "_comment": "Generated by CubETL",
#             "label": "product_category",
#             "levels": [
#                 {
#                     "attributes": [
#                         "pandacube_product_category"
#                     ],
#                     "key": "pandacube_product_category",
#                     "label": "product_category",
#                     "label_attribute": "pandacube_product_category",
#                     "name": "pandacube_product_category"
#                 }
#             ],
#             "name": "pandacube_product_category"
#         },
#         {
#             "_comment": "Generated by CubETL",
#             "label": "product_subcategory",
#             "levels": [
#                 {
#                     "attributes": [
#                         "pandacube_product_subcategory"
#                     ],
#                     "key": "pandacube_product_subcategory",
#                     "label": "product_subcategory",
#                     "label_attribute": "pandacube_product_subcategory",
#                     "name": "pandacube_product_subcategory"
#                 }
#             ],
#             "name": "pandacube_product_subcategory"
#         },
#         {
#             "_comment": "Generated by CubETL",
#             "label": "product_name",
#             "levels": [
#                 {
#                     "attributes": [
#                         "pandacube_product_name"
#                     ],
#                     "key": "pandacube_product_name",
#                     "label": "product_name",
#                     "label_attribute": "pandacube_product_name",
#                     "name": "pandacube_product_name"
#                 }
#             ],
#             "name": "pandacube_product_name"
#         },
#         {
#             "_comment": "Generated by CubETL",
#             "label": "product_unit",
#             "levels": [
#                 {
#                     "attributes": [
#                         "pandacube_product_unit"
#                     ],
#                     "key": "pandacube_product_unit",
#                     "label": "product_unit",
#                     "label_attribute": "pandacube_product_unit",
#                     "name": "pandacube_product_unit"
#                 }
#             ],
#             "name": "pandacube_product_unit"
#         },
#         {
#             "_comment": "Generated by CubETL",
#             "label": "vendor",
#             "levels": [
#                 {
#                     "attributes": [
#                         "pandacube_vendor"
#                     ],
#                     "key": "pandacube_vendor",
#                     "label": "vendor",
#                     "label_attribute": "pandacube_vendor",
#                     "name": "pandacube_vendor"
#                 }
#             ],
#             "name": "pandacube_vendor"
#         }
#     ]
# }
# sqlite:////tmp/cubesext-db-4kfh7hz1.sqlite3 /tmp/cubesext-model-2h84h583.json

# %%
cubesext.cubes_serve(db_url, model_path)
# Out:
# 2018-06-29 18:12:38,266 - INFO - Killing cubes process: 22954
# 2018-06-29 18:12:40,270 - INFO - Launching cubes slicer: /tmp/cubes-slicer-1l8o2x84.ini
# 2018-06-29 18:12:40,302 - INFO - Launched process: 23779

# %%
cubesext.cubesviewer_jupyter()
# Out:
#             <link rel="stylesheet" href="/nbextensions/cubesext/static/lib/bootstrap/bootstrap.css" />
#             <link rel="stylesheet" href="/nbextensions/cubesext/static/lib/angular-ui-grid/ui-grid.css" />
#             <link rel="stylesheet" href="/nbextensions/cubesext/static/lib/font-awesome/css/font-awesome.css" />
#             <link rel="stylesheet" href="/nbextensions/cubesext/static/lib/nvd3/nv.d3.css" />
#             <link rel="stylesheet" href="/nbextensions/cubesext/static/lib/cubesviewer/cubesviewer.css" />
#             <link rel="stylesheet" href="/nbextensions/cubesext/static/lib/bootstrap-submenu/css/bootstrap-submenu.css" /> <!-- after cubesviewer.css! -->
#
#             <!--<script src="/nbextensions/cubesext/static/lib/jquery/jquery.js"></script>-->
#             <!--<script src="/nbextensions/cubesext/static/lib/bootstrap/bootstrap.js"></script>-->
#             <script src="/nbextensions/cubesext/static/lib/bootstrap-submenu/js/bootstrap-submenu.js"></script>
#             <script src="/nbextensions/cubesext/static/lib/angular/angular.js"></script>
#             <script src="/nbextensions/cubesext/static/lib/angular-cookies/angular-cookies.js"></script>
#             <script src="/nbextensions/cubesext/static/lib/cubesviewer/cubesviewer.js"></script>
#             <script src="/nbextensions/cubesext/static/lib/angular-bootstrap/ui-bootstrap-tpls.js"></script>
#             <script src="/nbextensions/cubesext/static/lib/angular-ui-grid/ui-grid.js"></script>
#             <script src="/nbextensions/cubesext/static/lib/d3/d3.js"></script>
#             <script src="/nbextensions/cubesext/static/lib/nvd3/nv.d3.js"></script>
#             <!--<script src="/nbextensions/cubesext/static/lib/flotr2/flotr2.min.js"></script>-->
#
#             <div id="cv_embedded_01"><i>CubesViewer View</i></div>
#
#             <script type="text/javascript">
#
#               //Reference to the created view
#               var view1 = null;
#
#               // Initialize CubesViewer when document is ready
#               //$(document).ready(function() {
#               setTimeout(function() {
#
#                   console.debug("Initializing CubesViewer cell in Jupyter Notebook.");
#
#                   var cubesUrl = "http://localhost:5000";
#
#                   // Initialize CubesViewer system
#                   cubesviewer.init({
#                       cubesUrl: cubesUrl
#                   });
#
#                   // Add views
#                   cubesviewer.apply(function() {
#                       //view1 = cubesviewer.createView('#cv_embedded_01', "cube", serializedViewOrObject);
#                       var serializedView = {"mode":"summary", "cubename":"webshop_sales", "name": "Sample View"};
#
#                       view1 = cubesviewer.createView('#cv_embedded_01', "cubesutilscube01", serializedView);
#                   });
#
#               //});
#               }, 3000);
#
#             </script>

# %%
pandas.DataFrame([[1, 2, "Yes"], [3, 4, "No"]])
