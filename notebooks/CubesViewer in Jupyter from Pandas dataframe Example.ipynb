# %% [markdown]
# # CubesViewer in Jupyter from Pandas dataframe

# %%
import os
import sys

sys.path.append("../")

# %load_ext autoreload
# %autoreload 2

# %%
import pandas
import cubesext

# %%
CSV_FILE = 'fakedata-product.csv'

df = pandas.read_csv(CSV_FILE)
df['product_price'] = df['product_price'].apply(lambda x: float(x.replace(",", ".")))
#df['product_price'] = df['product_price'].astype(float)
df[:10]
# Out:
#      product_category product_subcategory  \
# 0  Office electronics         Calculators
# 1  Office electronics         Calculators
# 2  Office electronics         Calculators
# 3  Office electronics           Shredders
# 4  Office electronics           Shredders
# 5  Office electronics           Shredders
# 6  Office electronics            Printers
# 7  Office electronics            Printers
# 8  Office electronics            Printers
# 9  Office electronics          Appliances
#
#                                         product_name  product_price  \
# 0                                              TI-84         101.38
# 1                                             MS-80B           7.99
# 2                            P23 Printing Calculator          22.13
# 3                                  Burn-O-Matic 3000          29.99
# 4                          HideItShredder (720 cuts)          59.70
# 5                         ShredderMelter Pyromatic X          89.99
# 6                   Multifunction Machine PrintItAll         910.10
# 7                           Desktop A4 laser printer         249.16
# 8  GuttembergEco Movable Type Press (25 pages/h, 0W)         697.99
# 9                      SurpriseFlavor Coffee machine         299.99
#
#   product_unit             vendor  product_description
# 0        units  Tejas Instruments                  NaN
# 1        units             Ocasio                  NaN
# 2        units            Shannon                  NaN
# 3        units              Prost                  NaN
# 4        units              Prost                  NaN
# 5        units              Prost                  NaN
# 6        units            Shannon                  NaN
# 7        units            Shannon                  NaN
# 8        units            Shannon                  NaN
# 9        units              Prost                  NaN

# %%
(db_url, model_path) = cubesext.pandas2cubes(df)
print(db_url, model_path)
# Out:
# 2017-04-24 01:33:32,203 - INFO - Starting CubETL 1.0.5-devel
# 2017-04-24 01:33:32,222 - INFO - Connecting to database: sqlite:////tmp/pandacubes-db-pvfqyaqw.sqlite3
# 2017-04-24 01:33:32,275 - INFO - Processing cubesutils.export-cubes
# +-- Column: index [type=BIGINT, null=True, pk=False, fk=set()]
# +-- Column: product_category [type=TEXT, null=True, pk=False, fk=set()]
# +-- Column: product_subcategory [type=TEXT, null=True, pk=False, fk=set()]
# +-- Column: product_name [type=TEXT, null=True, pk=False, fk=set()]
# +-- Column: product_price [type=FLOAT, null=True, pk=False, fk=set()]
# +-- Column: product_unit [type=TEXT, null=True, pk=False, fk=set()]
# +-- Column: vendor [type=TEXT, null=True, pk=False, fk=set()]
# +-- Column: product_description [type=FLOAT, null=True, pk=False, fk=set()]
# {
#     "cubes": [
#         {
#             "_comment": "Generated by CubETL",
#             "aggregates": [
#                 {
#                     "function": "sum",
#                     "label": "product_price Sum",
#                     "measure": "product_price",
#                     "name": "product_price_sum"
#                 },
#                 {
#                     "function": "avg",
#                     "label": "product_price Avg",
#                     "measure": "product_price",
#                     "name": "product_price_avg"
#                 },
#                 {
#                     "function": "max",
#                     "label": "product_price Max",
#                     "measure": "product_price",
#                     "name": "product_price_max"
#                 },
#                 {
#                     "function": "min",
#                     "label": "product_price Min",
#                     "measure": "product_price",
#                     "name": "product_price_min"
#                 },
#                 {
#                     "function": "sum",
#                     "label": "product_description Sum",
#                     "measure": "product_description",
#                     "name": "product_description_sum"
#                 },
#                 {
#                     "function": "avg",
#                     "label": "product_description Avg",
#                     "measure": "product_description",
#                     "name": "product_description_avg"
#                 },
#                 {
#                     "function": "max",
#                     "label": "product_description Max",
#                     "measure": "product_description",
#                     "name": "product_description_max"
#                 },
#                 {
#                     "function": "min",
#                     "label": "product_description Min",
#                     "measure": "product_description",
#                     "name": "product_description_min"
#                 },
#                 {
#                     "function": "count",
#                     "label": "Record Count",
#                     "name": "record_count"
#                 }
#             ],
#             "details": [],
#             "dimensions": [
#                 "product_category",
#                 "product_subcategory",
#                 "product_name",
#                 "product_unit",
#                 "vendor"
#             ],
#             "joins": [],
#             "key": "index",
#             "label": "pandacube",
#             "mappings": {
#                 "product_category.product_category": "pandacube.product_category",
#                 "product_name.product_name": "pandacube.product_name",
#                 "product_subcategory.product_subcategory": "pandacube.product_subcategory",
#                 "product_unit.product_unit": "pandacube.product_unit",
#                 "vendor.vendor": "pandacube.vendor"
#             },
#             "measures": [
#                 {
#                     "label": "product_price",
#                     "name": "product_price"
#                 },
#                 {
#                     "label": "product_description",
#                     "name": "product_description"
#                 }
#             ],
#             "name": "pandacube"
#         }
#     ],
#     "dimensions": [
#         {
#             "_comment": "Generated by CubETL",
#             "label": "product_category",
#             "levels": [
#                 {
#                     "attributes": [
#                         "product_category"
#                     ],
#                     "key": "product_category",
#                     "label": "product_category",
#                     "label_attribute": "product_category",
#                     "name": "product_category"
#                 }
#             ],
#             "name": "product_category"
#         },
#         {
#             "_comment": "Generated by CubETL",
#             "label": "product_subcategory",
#             "levels": [
#                 {
#                     "attributes": [
#                         "product_subcategory"
#                     ],
#                     "key": "product_subcategory",
#                     "label": "product_subcategory",
#                     "label_attribute": "product_subcategory",
#                     "name": "product_subcategory"
#                 }
#             ],
#             "name": "product_subcategory"
#         },
#         {
#             "_comment": "Generated by CubETL",
#             "label": "product_name",
#             "levels": [
#                 {
#                     "attributes": [
#                         "product_name"
#                     ],
#                     "key": "product_name",
#                     "label": "product_name",
#                     "label_attribute": "product_name",
#                     "name": "product_name"
#                 }
#             ],
#             "name": "product_name"
#         },
#         {
#             "_comment": "Generated by CubETL",
#             "label": "product_unit",
#             "levels": [
#                 {
#                     "attributes": [
#                         "product_unit"
#                     ],
#                     "key": "product_unit",
#                     "label": "product_unit",
#                     "label_attribute": "product_unit",
#                     "name": "product_unit"
#                 }
#             ],
#             "name": "product_unit"
#         },
#         {
#             "_comment": "Generated by CubETL",
#             "label": "vendor",
#             "levels": [
#                 {
#                     "attributes": [
#                         "vendor"
#                     ],
#                     "key": "vendor",
#                     "label": "vendor",
#                     "label_attribute": "vendor",
#                     "name": "vendor"
#                 }
#             ],
#             "name": "vendor"
#         }
#     ]
# }
# sqlite:////tmp/pandacubes-db-pvfqyaqw.sqlite3 /tmp/pandacubes-model-d2a3fqry.json

# %%
cubesext.cubes_serve(db_url, model_path)
# Out:
# 2017-04-24 01:33:32,389 - INFO -  * Running on http://localhost:5000/ (Press CTRL+C to quit)
# 2017-04-24 01:33:43,591 - INFO - 127.0.0.1 - - [24/Apr/2017 01:33:43] "GET /info HTTP/1.1" 200 -
# 2017-04-24 01:33:43,747 - INFO - 127.0.0.1 - - [24/Apr/2017 01:33:43] "GET /cubes HTTP/1.1" 200 -
# 2017-04-24 01:33:45,479 - INFO - 127.0.0.1 - - [24/Apr/2017 01:33:45] "GET /cube/pandacube/model HTTP/1.1" 200 -
# 2017-04-24 01:33:45,660 - INFO - 127.0.0.1 - - [24/Apr/2017 01:33:45] "GET /cube/pandacube/aggregate HTTP/1.1" 200 -
# 2017-04-24 01:33:52,652 - INFO - 127.0.0.1 - - [24/Apr/2017 01:33:52] "GET /cube/pandacube/facts HTTP/1.1" 200 -
# 2017-04-24 01:35:08,879 - INFO - 127.0.0.1 - - [24/Apr/2017 01:35:08] "GET /cube/pandacube/aggregate?drilldown=product_category%40default%3Aproduct_category HTTP/1.1" 200 -

# %%
cubesext.cubesviewer_jupyter()

# %%
pandas.DataFrame([[1, 2, "Yes"], [3, 4, "No"]])
